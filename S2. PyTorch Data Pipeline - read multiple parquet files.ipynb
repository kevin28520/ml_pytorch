# %% [markdown]
# # S2. PyTorch Data Pipeline - read multiple parquet files
#
#
# ![alt text](utils/2_1.png "")
# - Data:
#     - Kaggle dataset: https://www.kaggle.com/datasets/mkechinov/ecommerce-behavior-data-from-multi-category-store
#
# ![alt text](utils/AWS_1.png "")
# ![alt text](utils/GCS_1.png "")
#
# - 目的：
# ![alt text](utils/2_3.png "")

# %% [markdown]
# # Step 1: 把数据保存为parquet格式

# %%
import os
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt

import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, DoubleType, BooleanType
from pyspark.sql.functions import col

import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
print(torch.__version__)
# Out:
# 2.0.1

# %%
spark = SparkSession.builder.appName("data_reading").getOrCreate()

schema = StructType() \
      .add("event_time", StringType(), True) \
      .add("event_type", StringType(), True) \
      .add("product_id", StringType(), True) \
      .add("category_id", StringType(), True) \
      .add("category_code", StringType(), True) \
      .add("brand", StringType(), True) \
      .add("price", DoubleType(), True) \
      .add("user_id", StringType(), True) \
      .add("user_session", StringType(), True)

# %%
# 2019-Oct.csv
# 数据量（行数）: 42,448,765

f = 'data/eCom_behavior_data/2019-Oct.csv'
N = 100000
df = spark.read.csv(f, schema=schema).limit(N)

print(f"data size: {df.count()}")
df.printSchema()
# Out:
# [Stage 101:========================================>              (32 + 8) / 43]
# data size: 100000
# root
#  |-- event_time: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- category_id: string (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_session: string (nullable = true)

# %%
df.show(3, False)
# Out:
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+-----+---------+------------------------------------+
# |event_time             |event_type|product_id|category_id        |category_code                      |brand   |price|user_id  |user_session                        |
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+-----+---------+------------------------------------+
# |event_time             |event_type|product_id|category_id        |category_code                      |brand   |null |user_id  |user_session                        |
# |2019-10-01 00:00:00 UTC|view      |44600062  |2103807459595387724|null                               |shiseido|35.79|541312140|72d76fde-8bb3-4e00-8c23-a032dfed738c|
# |2019-10-01 00:00:00 UTC|view      |3900821   |2053013552326770905|appliances.environment.water_heater|aqua    |33.2 |554748717|9333dfbd-b87a-4708-9857-6336556b0fcc|
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+-----+---------+------------------------------------+
# only showing top 3 rows

# %%
NUM_PARTITIONS = 100

folder = 'data/eCom_behavior_data/100K_dataset'
df.repartition(NUM_PARTITIONS).write.mode("overwrite").parquet(folder)
# Out:
# 23/06/11 20:15:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/11 20:15:52 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/11 20:15:52 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/11 20:15:53 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/11 20:15:53 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/11 20:15:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/11 20:15:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/11 20:15:55 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/11 20:15:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %%
for name in os.listdir(folder):
    if name.endswith('.parquet'):
        file_dir = f'{folder}/{name}'
        print(f'current partition file: {name}')
        temp = pd.read_parquet(file_dir)
        print(f'current partition data size: {temp.shape}\n')
# Out:
# current partition file: part-00021-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00055-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00068-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00094-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00049-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00074-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00088-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00000-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00036-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00042-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00083-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00063-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00017-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00093-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00052-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00026-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00007-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00073-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00078-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00084-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00045-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00031-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00010-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00064-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00098-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00059-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00092-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00027-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00053-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00072-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00006-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00079-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00085-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00030-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00044-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00065-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00099-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00011-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00058-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00054-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00020-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00069-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00095-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00048-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00001-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00075-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00089-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00043-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00037-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00082-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00016-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00062-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00090-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00018-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00025-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00051-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00070-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00004-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00039-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00087-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00032-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00046-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00067-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00013-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00056-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00022-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00097-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00003-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00077-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00041-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00035-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00008-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00080-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00029-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00014-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00060-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00023-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00057-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00096-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00076-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00002-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00034-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00040-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00081-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00009-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00028-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00061-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00015-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00019-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00091-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00050-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00024-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00005-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00071-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00038-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00086-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00047-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00033-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00012-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
#
# current partition file: part-00066-990b8e08-8e95-4ac3-8b16-988b46313b8f-c000.snappy.parquet
# current partition data size: (1000, 9)
